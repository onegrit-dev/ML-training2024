# %% [markdown]
# <a href="https://colab.research.google.com/github/onegrit-dev/ML-training2024/blob/main/1_3_1_ydata_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ydata-profiling によるEDA

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 12.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=b348e3ed54b32be922dba3001144d51da5db2b0d0b842420e56253fdfd7b3ade
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
import pandas as pd

# データの読み込み
df = pd.read_csv('231_カテゴリデータのエンコーディング.csv')
df
# Out:
#         名前  年齢 性別     身長    体重 喫煙有無 血液型
# 0     河田春香  28  女  159.8  61.6  非喫煙  AB
# 1     安藤祥子  47  女  157.5  52.3   喫煙   A
# 2      工藤淳  28  男  177.1  64.1   喫煙   O
# 3     稲田智美  38  女  162.0  51.8  非喫煙   O
# 4     大矢光希  42  男  172.6  78.7  非喫煙   A
# ..     ...  .. ..    ...   ...  ...  ..
# 195   永田大翔  44  男  171.2  61.3   喫煙   A
# 196   桜井大河  57  男  164.3  70.0  非喫煙   A
# 197  瀬戸口翔太  28  男  177.1  59.1  非喫煙   O
# 198    大坂奏  50  男  166.2  74.4  非喫煙  AB
# 199   佐藤大翔  13  男  159.1  41.4   喫煙   B
#
# [200 rows x 7 columns]

# %%
from ydata_profiling import ProfileReport

# EDA実行
report = ProfileReport(df)
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-21 06:06:04.257526&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# EDAを実行してプロファイルレポート作成
report = ProfileReport(df)
report.to_file('report.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 40802 (\N{CJK UNIFIED IDEOGRAPH-9F62}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 36523 (\N{CJK UNIFIED IDEOGRAPH-8EAB}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 38263 (\N{CJK UNIFIED IDEOGRAPH-9577}) missing from current font.
#   plt.savefig(
# ...

# %% [markdown]
# # zarque-profiling によるEDA

# %%
# !pip install japanize-matplotlib
import japanize_matplotlib

# %%
# !pip install zarque-profiling

# %%
import pandas as pd
from zarque_profiling import ProfileReport

# データの読み込み
df = pd.read_csv('231_カテゴリデータのエンコーディング.csv')

# EDAを実行してプロファイルレポート作成
report = ProfileReport(
    df,
    minimal=False,
    font_family='IPAexGothic',
)
report
